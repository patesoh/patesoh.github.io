# %% [markdown]
# # WeatherPy
# ----
#
# ### Observations
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). While it seems like the northern hemisphere tends to be warmer this time of year in the scatter plot than the southern hemisphere, it is very important to note that there is no data available for cities in the southern hemisphere between -60 degrees and - 90 degrees latitude (as compared to the relative abundance of data, all the way up to 80 degrees latitude in the northern hemisphere.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 20, 40, ~80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed.
# * There is no strong relationship between latitude and humidity.
# * It is interesting to see that, when looking at longitude vs. max. temp, most cities analyzed have temperatures between 0 and 50C for this time of the year, indicating the cities analyzed are mostly from the parts of the world experiencing the summer season.
# * Also, while looking at longitude vs. other variables(humidity, cloudiness), there does not seem to be any discernable trends.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import os

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = os.path.join("Output Data","cities.csv")

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs, 
lat_lngs = []
cities = []
countries = []
citycountry = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city,associated country and a combined "city,country" string for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    country = citipy.nearest_city(lat_lng[0], lat_lng[1]).country_code
    city_country=str(city) + "," + str(country)
    # If the city is unique, then add it to our cities list, 
    if city not in cities:
        cities.append(city)
        countries.append(country)
        citycountry.append(city_country)

# Print the city count to confirm sufficient count
print(f'The number of cities is {len(cities)}.')
# Out:
# The number of cities is 628.

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

# Build partial query URL
query_url = f"{url}&appid={api_key}&units={units}&q="



# create lists to hold lat, lon, windspeed, cloudiness, etc.
Lat = []
Lon = []
Temp = []
Wind = []
Cloud = []
Hum = []
City = []
Country = []
Date = []


#set the counter to zero for record number keeping
counter = 1

print(f'Beginning Data Retrieval')
print(f'---------------------------')


for city in citycountry:
    try:
        # assemble url and make API request, add to the respective lists, and create print log for each API call
        finalurl= query_url + city
        response = requests.get(finalurl).json()
        print(f"Processing record no.{counter}|{city}.")
        counter = counter + 1
        Lat.append(response['coord']['lat'])
        Lon.append(response['coord']['lon'])
        Temp.append(response['main']['temp_max'])
        Wind.append(response['wind']['speed'])
        Cloud.append(response['clouds']['all'])
        Hum.append(response['main']['humidity'])
        City.append(response['name'])
        Country.append(response['sys']['country'])
        Date.append(response['dt'])
        time.sleep(1.01)
    except:
        print("City not found... skipping.")

print('--------------------------')
print('Data Retrieval Complete')
print('--------------------------')
# Out:
# Beginning Data Retrieval
# ---------------------------
# Processing record no.1|karaidel,ru.
# Processing record no.2|saskylakh,ru.
# Processing record no.3|sitka,us.
# Processing record no.4|macas,ec.
# Processing record no.5|ushuaia,ar.
# Processing record no.6|bluff,nz.
# Processing record no.7|hermanus,za.
# Processing record no.8|lompoc,us.
# Processing record no.9|mys shmidta,ru.
# City not found... skipping.
# Processing record no.10|hilo,us.
# Processing record no.11|san patricio,mx.
# Processing record no.12|sentyabrskiy,ru.
# City not found... skipping.
# Processing record no.13|grajau,br.
# City not found... skipping.
# Processing record no.14|vanimo,pg.
# Processing record no.15|mujiayingzi,cn.
# Processing record no.16|unidad,ph.
# Processing record no.17|bethel,us.
# Processing record no.18|roald,no.
# Processing record no.19|mataura,pf.
# City not found... skipping.
# Processing record no.20|rikitea,pf.
# Processing record no.21|comodoro rivadavia,ar.
# Processing record no.22|puerto ayora,ec.
# Processing record no.23|upernavik,gl.
# Processing record no.24|atuona,pf.
# Processing record no.25|taolanaro,mg.
# City not found... skipping.
# Processing record no.26|ilulissat,gl.
# Processing record no.27|hobart,au.
# Processing record no.28|arkadelphia,us.
# Processing record no.29|illoqqortoormiut,gl.
# City not found... skipping.
# Processing record no.30|port alfred,za.
# Processing record no.31|punta arenas,cl.
# Processing record no.32|bathsheba,bb.
# Processing record no.33|hobyo,so.
# Processing record no.34|kununurra,au.
# Processing record no.35|birjand,ir.
# Processing record no.36|bredasdorp,za.
# Processing record no.37|butaritari,ki.
# Processing record no.38|attawapiskat,ca.
# City not found... skipping.
# Processing record no.39|kapaa,us.
# Processing record no.40|ahuimanu,us.
# Processing record no.41|vaini,to.
# Processing record no.42|avarua,ck.
# Processing record no.43|clyde river,ca.
# Processing record no.44|devarkonda,in.
# Processing record no.45|labuhan,id.
# Processing record no.46|hammerfest,no.
# Processing record no.47|provideniya,ru.
# Processing record no.48|port macquarie,au.
# Processing record no.49|sarankhola,bd.
# Processing record no.50|lebu,cl.
# Processing record no.51|oxbow,ca.
# Processing record no.52|birao,cf.
# Processing record no.53|isangel,vu.
# Processing record no.54|albany,au.
# Processing record no.55|manta,ec.
# Processing record no.56|chernyshevskiy,ru.
# Processing record no.57|moron,mn.
# Processing record no.58|hithadhoo,mv.
# Processing record no.59|capiibary,py.
# Processing record no.60|araguatins,br.
# City not found... skipping.
# Processing record no.61|korla,cn.
# Processing record no.62|lensk,ru.
# Processing record no.63|damara,cf.
# Processing record no.64|east london,za.
# Processing record no.65|fortuna,us.
# Processing record no.66|najran,sa.
# Processing record no.67|annau,tm.
# Processing record no.68|natitingou,bj.
# Processing record no.69|jati,pk.
# Processing record no.70|peniche,pt.
# Processing record no.71|amambai,br.
# Processing record no.72|kalmunai,lk.
# Processing record no.73|rockport,us.
# Processing record no.74|tsihombe,mg.
# City not found... skipping.
# Processing record no.75|juneau,us.
# Processing record no.76|vardo,no.
# Processing record no.77|sorvag,fo.
# City not found... skipping.
# Processing record no.78|lebedyn,ua.
# Processing record no.79|camacha,pt.
# Processing record no.80|ixtapa,mx.
# Processing record no.81|moree,au.
# Processing record no.82|tasiilaq,gl.
# Processing record no.83|olga,ru.
# Processing record no.84|mahebourg,mu.
# Processing record no.85|ribeira brava,cv.
# City not found... skipping.
# Processing record no.86|paamiut,gl.
# Processing record no.87|samarai,pg.
# Processing record no.88|charters towers,au.
# Processing record no.89|mar del plata,ar.
# Processing record no.90|saint-georges,gf.
# City not found... skipping.
# Processing record no.91|longyearbyen,sj.
# Processing record no.92|lyubeshiv,ua.
# City not found... skipping.
# Processing record no.93|qaanaaq,gl.
# Processing record no.94|tiksi,ru.
# Processing record no.95|garowe,so.
# Processing record no.96|tuktoyaktuk,ca.
# Processing record no.97|constitucion,mx.
# Processing record no.98|nizhniy tsasuchey,ru.
# Processing record no.99|castro,cl.
# Processing record no.100|minab,ir.
# Processing record no.101|iqaluit,ca.
# Processing record no.102|tabuk,sa.
# Processing record no.103|tambopata,pe.
# City not found... skipping.
# Processing record no.104|tukrah,ly.
# City not found... skipping.
# Processing record no.105|vitry-le-francois,fr.
# Processing record no.106|kruisfontein,za.
# Processing record no.107|honiara,sb.
# Processing record no.108|rincon,an.
# City not found... skipping.
# Processing record no.109|barentsburg,sj.
# City not found... skipping.
# Processing record no.110|tezu,in.
# Processing record no.111|leningradskiy,ru.
# Processing record no.112|port elizabeth,za.
# Processing record no.113|saint-philippe,re.
# Processing record no.114|changji,cn.
# Processing record no.115|busselton,au.
# Processing record no.116|prince rupert,ca.
# Processing record no.117|saldanha,za.
# Processing record no.118|jamestown,sh.
# Processing record no.119|broome,au.
# Processing record no.120|sao filipe,cv.
# Processing record no.121|visby,se.
# Processing record no.122|gushikawa,jp.
# Processing record no.123|mount gambier,au.
# Processing record no.124|ancud,cl.
# Processing record no.125|lorengau,pg.
# Processing record no.126|tabiauea,ki.
# City not found... skipping.
# Processing record no.127|torbay,ca.
# Processing record no.128|oksfjord,no.
# Processing record no.129|pisco,pe.
# Processing record no.130|sabang,id.
# Processing record no.131|ambilobe,mg.
# Processing record no.132|benjamin constant,br.
# Processing record no.133|kasongo-lunda,cd.
# Processing record no.134|meybod,ir.
# Processing record no.135|ribeira grande,pt.
# Processing record no.136|veselynove,ua.
# Processing record no.137|udachnyy,ru.
# Processing record no.138|nizhneyansk,ru.
# City not found... skipping.
# Processing record no.139|worthington,us.
# Processing record no.140|dicabisagan,ph.
# Processing record no.141|kiunga,pg.
# Processing record no.142|namatanai,pg.
# Processing record no.143|ferme-neuve,ca.
# Processing record no.144|villamontes,bo.
# Processing record no.145|sergach,ru.
# Processing record no.146|henties bay,na.
# Processing record no.147|kashan,ir.
# Processing record no.148|sawtell,au.
# Processing record no.149|concepcion del oro,mx.
# Processing record no.150|kahului,us.
# Processing record no.151|kazalinsk,kz.
# City not found... skipping.
# Processing record no.152|airai,pw.
# City not found... skipping.
# Processing record no.153|christchurch,nz.
# Processing record no.154|bosaso,so.
# Processing record no.155|robertsport,lr.
# Processing record no.156|yanchukan,ru.
# City not found... skipping.
# Processing record no.157|panjab,af.
# Processing record no.158|cidreira,br.
# Processing record no.159|cobija,bo.
# Processing record no.160|yellowknife,ca.
# Processing record no.161|katsuura,jp.
# Processing record no.162|pevek,ru.
# Processing record no.163|barrow,us.
# Processing record no.164|victoria,sc.
# Processing record no.165|sovetskiy,ru.
# Processing record no.166|ziro,in.
# Processing record no.167|oudtshoorn,za.
# Processing record no.168|northam,au.
# Processing record no.169|antalaha,mg.
# Processing record no.170|lamu,ke.
# Processing record no.171|bababe,mr.
# City not found... skipping.
# Processing record no.172|san isidro,ph.
# Processing record no.173|acapulco,mx.
# Processing record no.174|muroto,jp.
# Processing record no.175|paciran,id.
# Processing record no.176|beba,eg.
# City not found... skipping.
# Processing record no.177|jaisalmer,in.
# Processing record no.178|ippy,cf.
# Processing record no.179|rio grande,br.
# Processing record no.180|maliq,al.
# Processing record no.181|jacareacanga,br.
# Processing record no.182|new norfolk,au.
# Processing record no.183|qui nhon,vn.
# City not found... skipping.
# Processing record no.184|nsanje,mw.
# Processing record no.185|vangaindrano,mg.
# Processing record no.186|port blair,in.
# Processing record no.187|dikson,ru.
# Processing record no.188|ambodifototra,mg.
# City not found... skipping.
# Processing record no.189|kawalu,id.
# Processing record no.190|hasaki,jp.
# Processing record no.191|chokurdakh,ru.
# Processing record no.192|karratha,au.
# Processing record no.193|bambous virieux,mu.
# Processing record no.194|presidente dutra,br.
# Processing record no.195|richards bay,za.
# Processing record no.196|tuatapere,nz.
# Processing record no.197|nemuro,jp.
# Processing record no.198|opuwo,na.
# Processing record no.199|inverell,au.
# Processing record no.200|artyk,ru.
# City not found... skipping.
# Processing record no.201|esso,ru.
# Processing record no.202|gornopravdinsk,ru.
# Processing record no.203|goundam,ml.
# Processing record no.204|souillac,mu.
# Processing record no.205|duobao,cn.
# Processing record no.206|port lincoln,au.
# Processing record no.207|svetlogorsk,ru.
# Processing record no.208|imeni poliny osipenko,ru.
# Processing record no.209|tulun,ru.
# Processing record no.210|oranjestad,aw.
# Processing record no.211|quatre cocos,mu.
# Processing record no.212|norman wells,ca.
# Processing record no.213|moerai,pf.
# Processing record no.214|zhanatas,kz.
# City not found... skipping.
# Processing record no.215|pakdasht,ir.
# Processing record no.216|pajapan,mx.
# Processing record no.217|ponta do sol,cv.
# Processing record no.218|narsaq,gl.
# Processing record no.219|bengkulu,id.
# City not found... skipping.
# Processing record no.220|pekan,my.
# Processing record no.221|yeppoon,au.
# Processing record no.222|antsohihy,mg.
# Processing record no.223|fairbanks,us.
# Processing record no.224|tomatlan,mx.
# Processing record no.225|arraial do cabo,br.
# Processing record no.226|phan thiet,vn.
# Processing record no.227|vaitupu,wf.
# City not found... skipping.
# Processing record no.228|kansanshi,zm.
# Processing record no.229|bam,ir.
# Processing record no.230|petropavlovsk-kamchatskiy,ru.
# Processing record no.231|south sioux city,us.
# Processing record no.232|one hundred mile house,ca.
# City not found... skipping.
# Processing record no.233|maldonado,uy.
# Processing record no.234|esperance,au.
# Processing record no.235|makow mazowiecki,pl.
# Processing record no.236|severo-kurilsk,ru.
# Processing record no.237|beyneu,kz.
# Processing record no.238|rosarito,mx.
# Processing record no.239|apple valley,us.
# Processing record no.240|cabra,ph.
# Processing record no.241|amderma,ru.
# City not found... skipping.
# Processing record no.242|cockburn town,tc.
# Processing record no.243|buraydah,sa.
# Processing record no.244|nabire,id.
# Processing record no.245|kuche,cn.
# City not found... skipping.
# Processing record no.246|belushya guba,ru.
# City not found... skipping.
# Processing record no.247|mattru,sl.
# Processing record no.248|tautira,pf.
# Processing record no.249|vanino,ru.
# Processing record no.250|dingle,ie.
# Processing record no.251|klaksvik,fo.
# Processing record no.252|kaitangata,nz.
# Processing record no.253|cilegon,id.
# Processing record no.254|cabo san lucas,mx.
# Processing record no.255|samusu,ws.
# City not found... skipping.
# Processing record no.256|trairi,br.
# Processing record no.257|buin,cl.
# Processing record no.258|khomutovka,ru.
# Processing record no.259|san rafael,ar.
# Processing record no.260|palmas,br.
# Processing record no.261|codrington,ag.
# City not found... skipping.
# Processing record no.262|kristiinankaupunki,fi.
# City not found... skipping.
# Processing record no.263|bealanana,mg.
# Processing record no.264|kisangani,cd.
# Processing record no.265|kavieng,pg.
# Processing record no.266|marsh harbour,bs.
# Processing record no.267|chamonix-mont-blanc,fr.
# Processing record no.268|naze,jp.
# Processing record no.269|mahibadhoo,mv.
# Processing record no.270|iquique,cl.
# Processing record no.271|tual,id.
# Processing record no.272|ostrovnoy,ru.
# Processing record no.273|elizabeth city,us.
# Processing record no.274|samalaeulu,ws.
# City not found... skipping.
# Processing record no.275|takoradi,gh.
# Processing record no.276|noumea,nc.
# Processing record no.277|boguchany,ru.
# Processing record no.278|port hardy,ca.
# Processing record no.279|guerrero negro,mx.
# Processing record no.280|iranshahr,ir.
# Processing record no.281|lasa,cn.
# City not found... skipping.
# Processing record no.282|coihaique,cl.
# Processing record no.283|ust-tsilma,ru.
# Processing record no.284|dongsheng,cn.
# Processing record no.285|cape town,za.
# Processing record no.286|portland,au.
# Processing record no.287|atar,mr.
# Processing record no.288|sisimiut,gl.
# Processing record no.289|georgetown,sh.
# Processing record no.290|sao jose da coroa grande,br.
# Processing record no.291|nikolskoye,ru.
# Processing record no.292|batagay,ru.
# Processing record no.293|sola,vu.
# Processing record no.294|srednekolymsk,ru.
# Processing record no.295|hay river,ca.
# Processing record no.296|sinnamary,gf.
# Processing record no.297|dengzhou,cn.
# Processing record no.298|agirish,ru.
# Processing record no.299|san quintin,mx.
# City not found... skipping.
# Processing record no.300|vestmannaeyjar,is.
# Processing record no.301|chuy,uy.
# Processing record no.302|kargopol,ru.
# Processing record no.303|tambilil,ph.
# Processing record no.304|vigrestad,no.
# Processing record no.305|akyab,mm.
# City not found... skipping.
# Processing record no.306|lynn haven,us.
# Processing record no.307|saint anthony,ca.
# City not found... skipping.
# Processing record no.308|san luis,ar.
# Processing record no.309|kodiak,us.
# Processing record no.310|karangampel,id.
# Processing record no.311|prainha,br.
# Processing record no.312|nioro,ml.
# City not found... skipping.
# Processing record no.313|alice springs,au.
# Processing record no.314|yuanping,cn.
# Processing record no.315|abha,sa.
# Processing record no.316|flinders,au.
# Processing record no.317|limoeiro do ajuru,br.
# Processing record no.318|santa rosa,ar.
# Processing record no.319|mehamn,no.
# Processing record no.320|doha,kw.
# City not found... skipping.
# Processing record no.321|saint george,bm.
# Processing record no.322|tabialan,ph.
# City not found... skipping.
# Processing record no.323|hovd,mn.
# Processing record no.324|yar-sale,ru.
# Processing record no.325|goiatuba,br.
# Processing record no.326|araouane,ml.
# Processing record no.327|carnarvon,au.
# Processing record no.328|lunca banului,ro.
# Processing record no.329|cherskiy,ru.
# Processing record no.330|benito juarez,mx.
# Processing record no.331|yulara,au.
# Processing record no.332|naryan-mar,ru.
# Processing record no.333|asau,tv.
# City not found... skipping.
# Processing record no.334|bur gabo,so.
# City not found... skipping.
# Processing record no.335|nizhnyaya salda,ru.
# Processing record no.336|jiangyou,cn.
# Processing record no.337|luderitz,na.
# Processing record no.338|galesong,id.
# Processing record no.339|lagoa,pt.
# Processing record no.340|salalah,om.
# Processing record no.341|bilma,ne.
# Processing record no.342|nanortalik,gl.
# Processing record no.343|grand-santi,gf.
# Processing record no.344|taungdwingyi,mm.
# Processing record no.345|berezovyy,ru.
# Processing record no.346|dunedin,nz.
# Processing record no.347|zyryanka,ru.
# Processing record no.348|pekan nenas,my.
# Processing record no.349|sambava,mg.
# Processing record no.350|severouralsk,ru.
# Processing record no.351|ranong,th.
# Processing record no.352|zhanakorgan,kz.
# Processing record no.353|jimo,cn.
# Processing record no.354|nevel,ru.
# Processing record no.355|waitati,nz.
# Processing record no.356|adwa,et.
# Processing record no.357|wanning,cn.
# Processing record no.358|kathu,za.
# Processing record no.359|granadilla de abona,es.
# Processing record no.360|talnakh,ru.
# Processing record no.361|hervey bay,au.
# Processing record no.362|biak,id.
# Processing record no.363|maarianhamina,fi.
# City not found... skipping.
# Processing record no.364|waipawa,nz.
# Processing record no.365|yuancheng,cn.
# Processing record no.366|bo rai,th.
# Processing record no.367|nouadhibou,mr.
# Processing record no.368|george,za.
# Processing record no.369|tumannyy,ru.
# City not found... skipping.
# Processing record no.370|barranca,pe.
# Processing record no.371|bima,id.
# Processing record no.372|popondetta,pg.
# Processing record no.373|khani,ru.
# City not found... skipping.
# Processing record no.374|westport,nz.
# Processing record no.375|toucheng,tw.
# Processing record no.376|walvis bay,na.
# Processing record no.377|nantucket,us.
# Processing record no.378|quelimane,mz.
# Processing record no.379|bitkine,td.
# Processing record no.380|faya,td.
# City not found... skipping.
# Processing record no.381|leczyca,pl.
# Processing record no.382|japura,br.
# City not found... skipping.
# Processing record no.383|khatanga,ru.
# Processing record no.384|toliary,mg.
# City not found... skipping.
# Processing record no.385|voila,ro.
# Processing record no.386|shenjiamen,cn.
# Processing record no.387|siva,ru.
# Processing record no.388|colon,pa.
# Processing record no.389|hofn,is.
# Processing record no.390|bogorodskoye,ru.
# Processing record no.391|north bend,us.
# Processing record no.392|palmares,cr.
# Processing record no.393|faanui,pf.
# Processing record no.394|mercedes,ar.
# Processing record no.395|abay,kz.
# Processing record no.396|alihe,cn.
# Processing record no.397|joshimath,in.
# Processing record no.398|damavand,ir.
# Processing record no.399|cap malheureux,mu.
# Processing record no.400|jasper,ca.
# Processing record no.401|karauzyak,uz.
# City not found... skipping.
# Processing record no.402|conde,br.
# Processing record no.403|macaboboni,ph.
# City not found... skipping.
# Processing record no.404|half moon bay,us.
# Processing record no.405|meulaboh,id.
# Processing record no.406|vao,nc.
# Processing record no.407|marcona,pe.
# City not found... skipping.
# Processing record no.408|caxito,ao.
# Processing record no.409|maine-soroa,ne.
# Processing record no.410|mecca,sa.
# Processing record no.411|salisbury,ca.
# Processing record no.412|taoudenni,ml.
# Processing record no.413|paradise,us.
# Processing record no.414|manokwari,id.
# Processing record no.415|beisfjord,no.
# Processing record no.416|tra vinh,vn.
# Processing record no.417|thompson,ca.
# Processing record no.418|hami,cn.
# Processing record no.419|aswan,eg.
# Processing record no.420|merauke,id.
# Processing record no.421|marzuq,ly.
# City not found... skipping.
# Processing record no.422|kirkenaer,no.
# Processing record no.423|lebyazhye,ru.
# Processing record no.424|huilong,cn.
# Processing record no.425|zhigansk,ru.
# Processing record no.426|tilichiki,ru.
# Processing record no.427|sokolo,ml.
# Processing record no.428|achisay,kz.
# City not found... skipping.
# Processing record no.429|polyarnyy,ru.
# Processing record no.430|nara,ml.
# Processing record no.431|katsiveli,ua.
# City not found... skipping.
# Processing record no.432|kiomboi,tz.
# Processing record no.433|ust-kut,ru.
# Processing record no.434|broken hill,au.
# Processing record no.435|beringovskiy,ru.
# Processing record no.436|tucuma,br.
# City not found... skipping.
# Processing record no.437|porbandar,in.
# Processing record no.438|kavaratti,in.
# Processing record no.439|geresk,af.
# City not found... skipping.
# Processing record no.440|thunder bay,ca.
# Processing record no.441|tanjong malim,my.
# City not found... skipping.
# Processing record no.442|orapa,bw.
# Processing record no.443|umm durman,sd.
# City not found... skipping.
# Processing record no.444|pangani,tz.
# Processing record no.445|mogadishu,so.
# Processing record no.446|laguna,br.
# City not found... skipping.
# Processing record no.447|mezen,ru.
# Processing record no.448|awjilah,ly.
# Processing record no.449|amapa,br.
# Processing record no.450|plonsk,pl.
# Processing record no.451|guisa,cu.
# Processing record no.452|douglas,us.
# Processing record no.453|soyo,ao.
# Processing record no.454|solnechnyy,ru.
# Processing record no.455|ucluelet,ca.
# Processing record no.456|khuzhir,ru.
# Processing record no.457|auki,sb.
# Processing record no.458|khokholskiy,ru.
# City not found... skipping.
# Processing record no.459|nyurba,ru.
# Processing record no.460|sribne,ua.
# Processing record no.461|atikokan,ca.
# Processing record no.462|zhuanghe,cn.
# Processing record no.463|adrar,dz.
# Processing record no.464|yancheng,cn.
# Processing record no.465|nola,cf.
# Processing record no.466|san cristobal,ec.
# Processing record no.467|sataua,ws.
# City not found... skipping.
# Processing record no.468|samana,do.
# City not found... skipping.
# Processing record no.469|gamboula,cf.
# Processing record no.470|elat,il.
# City not found... skipping.
# Processing record no.471|verkhnyaya inta,ru.
# Processing record no.472|saleaula,ws.
# City not found... skipping.
# Processing record no.473|bandarbeyla,so.
# Processing record no.474|rafai,cf.
# Processing record no.475|tazovskiy,ru.
# Processing record no.476|mergui,mm.
# City not found... skipping.
# Processing record no.477|north augusta,us.
# Processing record no.478|la asuncion,ve.
# Processing record no.479|wanxian,cn.
# Processing record no.480|ostersund,se.
# Processing record no.481|eldikan,ru.
# City not found... skipping.
# Processing record no.482|porangatu,br.
# Processing record no.483|urcos,pe.
# Processing record no.484|pasni,pk.
# Processing record no.485|maymyo,mm.
# Processing record no.486|pozo colorado,py.
# Processing record no.487|westlock,ca.
# Processing record no.488|dandong,cn.
# Processing record no.489|blonduos,is.
# City not found... skipping.
# Processing record no.490|qandala,so.
# Processing record no.491|vila velha,br.
# Processing record no.492|alugan,ph.
# Processing record no.493|manoel urbano,br.
# Processing record no.494|lobito,ao.
# Processing record no.495|kaeo,nz.
# Processing record no.496|los llanos de aridane,es.
# Processing record no.497|sakakah,sa.
# City not found... skipping.
# Processing record no.498|bonavista,ca.
# Processing record no.499|darhan,mn.
# Processing record no.500|mitu,co.
# Processing record no.501|altay,cn.
# Processing record no.502|olafsvik,is.
# City not found... skipping.
# Processing record no.503|la rioja,ar.
# Processing record no.504|kabalo,cd.
# Processing record no.505|along,in.
# Processing record no.506|chumikan,ru.
# Processing record no.507|igarape-miri,br.
# City not found... skipping.
# Processing record no.508|xinzhi,cn.
# Processing record no.509|storforshei,no.
# Processing record no.510|caravelas,br.
# Processing record no.511|tarhunah,ly.
# City not found... skipping.
# Processing record no.512|grand forks,us.
# Processing record no.513|teknaf,bd.
# Processing record no.514|tagusao,ph.
# Processing record no.515|nome,us.
# Processing record no.516|tafresh,ir.
# Processing record no.517|arica,cl.
# Processing record no.518|halifax,ca.
# Processing record no.519|madimba,tz.
# Processing record no.520|tabou,ci.
# Processing record no.521|yaan,cn.
# City not found... skipping.
# Processing record no.522|mocuba,mz.
# Processing record no.523|geraldton,au.
# Processing record no.524|zhangye,cn.
# Processing record no.525|harper,lr.
# Processing record no.526|husavik,is.
# Processing record no.527|kuvshinovo,ru.
# Processing record no.528|teya,ru.
# Processing record no.529|rochester,us.
# Processing record no.530|nurota,uz.
# Processing record no.531|sangmelima,cm.
# Processing record no.532|shimanovsk,ru.
# Processing record no.533|bang mun nak,th.
# Processing record no.534|balkanabat,tm.
# Processing record no.535|mingshui,cn.
# Processing record no.536|miri,my.
# Processing record no.537|saveh,ir.
# Processing record no.538|sergeyevka,kz.
# Processing record no.539|palabuhanratu,id.
# City not found... skipping.
# Processing record no.540|evensk,ru.
# Processing record no.541|mendoza,ar.
# Processing record no.542|port-de-paix,ht.
# City not found... skipping.
# Processing record no.543|fraga,es.
# Processing record no.544|nanding,cn.
# Processing record no.545|jovellanos,cu.
# Processing record no.546|poya,nc.
# Processing record no.547|topolobampo,mx.
# Processing record no.548|waingapu,id.
# Processing record no.549|moindou,nc.
# Processing record no.550|palakollu,in.
# Processing record no.551|maniitsoq,gl.
# Processing record no.552|kidal,ml.
# Processing record no.553|khasan,ru.
# Processing record no.554|fare,pf.
# Processing record no.555|qaqortoq,gl.
# Processing record no.556|ribe,dk.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# --------------------------
# Data Retrieval Complete
# --------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
citydata=pd.DataFrame({"City":City,"Country":Country,"Latitude":Lat,"Longitude": Lon,
                      "Max. Temp.(C)": Temp, "Humidity(%)": Hum, "Cloudiness(%)": Cloud,
                      "Windspeed(mph)": Wind, "Date": Date})
citydata=citydata.drop_duplicates(["City","Country"])
#print count for the df to ensure there are >500 cities
print(citydata.count())
#print the output csv file and drop the index column
output = citydata.to_csv(output_data_file, index=False)
output
#Preview the dataframe
citydata.head()
#previewing the dataframe revealed that date column was in unix format. 
#convert date from unix timestamp to yyyy-mm-dd
from datetime import datetime, timedelta
start = datetime(1970, 1, 1)  # Unix epoch start time
citydata['Date'] = citydata['Date'].apply(lambda x: start + timedelta(seconds=x))
citydata['Date'] = citydata['Date'].apply(lambda x: x.strftime('%Y-%m-%d'))
#preview the dataframe again
citydata.head()
# Out:
# City              477
# Country           477
# Latitude          477
# Longitude         477
# Max. Temp.(C)     477
# Humidity(%)       477
# Cloudiness(%)     477
# Windspeed(mph)    477
# Date              477
# dtype: int64
#         City Country  Latitude  Longitude  Max. Temp.(C)  Humidity(%)  \
# 0   Karaidel      RU     55.83      56.91          10.73           75
# 1  Saskylakh      RU     71.97     114.09           1.93           90
# 2      Sitka      US     37.17     -99.65          27.78           50
# 3      Macas      EC     -2.30     -78.12          25.00           73
# 4    Ushuaia      AR    -54.81     -68.31           4.00           80
#
#    Cloudiness(%)  Windspeed(mph)        Date
# 0              4            1.81  2019-06-02
# 1             99            5.52  2019-06-02
# 2             86            4.47  2019-06-02
# 3             20            4.10  2019-06-02
# 4             75            2.20  2019-06-02

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(y=citydata["Max. Temp.(C)"],x=citydata["Latitude"], color="#4682b4",
            edgecolors="black",marker='o',alpha=1)
plt.title(f'City Latitude vs Max Temperature, ({citydata["Date"][0]})')
plt.ylabel('Max Temperature(Celsius)')
plt.xlabel('Latitude')
plt.xlim(-85,85)
plt.grid(True)
plt.show()
plt.savefig("Latitude vs. Max. Temperature.jpeg")

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(y=citydata["Humidity(%)"],x=citydata["Latitude"], color="#4682b4",
            edgecolors="black",marker='o',alpha=1)
plt.title(f'City Latitude vs Humidity, ({citydata["Date"][0]})')
plt.ylabel('Humidity(%)')
#Set ylim to ignore 200%+ humidity values for Iquitos,PE and Paita, PE, which are most likely typos 
plt.ylim(0,105)
plt.xlabel('Latitude')
plt.grid(True)
plt.show()
plt.savefig("City Latitude vs. Humidity.jpeg")

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(y=citydata["Cloudiness(%)"],x=citydata["Latitude"], color="#4682b4",
            edgecolors="black",marker='o',alpha=1)
plt.title(f'City Latitude vs Cloudiness, ({citydata["Date"][0]})')
plt.ylabel('Cloudiness(%)')
#Set ylim for optimal view of datapoints
plt.ylim(-5,105)
plt.xlabel('Latitude')
plt.grid(True)
plt.show()
plt.savefig("City Latitude vs. Cloudiness.jpeg")

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(y=citydata["Windspeed(mph)"],x=citydata["Latitude"], color="#4682b4",
            edgecolors="black",marker='o',alpha=1)
plt.title(f'City Latitude vs Windspeed, ({citydata["Date"][0]})')
plt.ylabel('Windspeed(mph)')
plt.xlabel('Latitude')
plt.grid(True)
plt.show()
plt.savefig("City Latitude vs. Windspeed.jpeg")

# %%
#### Longitude vs. Humidity Plot

# %%
plt.scatter(y=citydata["Humidity(%)"],x=citydata["Longitude"], color="#4682b4",
            edgecolors="black",marker='o',alpha=1)
plt.title(f'City Longitude vs Humidity, ({citydata["Date"][0]})')
plt.ylabel('Humidity(%)')
#Set ylim to ignore 200%+ humidity values for Iquitos,PE and Paita, PE, which are most likely typos 
plt.ylim(0,105)
plt.xlabel('Longitude')
plt.grid(True)
plt.show()
plt.savefig("City Longitude vs. Humidity.jpeg")

# %%
plt.scatter(y=citydata["Max. Temp.(C)"],x=citydata["Longitude"], color="#4682b4",
            edgecolors="black",marker='o',alpha=1)
plt.title(f'City Longitude vs Max. Temp., ({citydata["Date"][0]})')
plt.ylabel('Max. Temp.(C)')
#Set ylim to ignore 200%+ humidity values for Iquitos,PE and Paita, PE, which are most likely typos 
plt.ylim(-100,100)
plt.xlabel('Longitude')
plt.grid(True)
plt.show()
plt.savefig("City Longitude vs. Max. Temp(C).jpeg")

# %%
plt.scatter(y=citydata["Windspeed(mph)"],x=citydata["Longitude"], color="#4682b4",
            edgecolors="black",marker='o',alpha=1)
plt.title(f'City Longitude vs Windspeed, ({citydata["Date"][0]})')
plt.ylabel('Windspeed(mph)')
plt.xlabel('Longitude')
plt.grid(True)
plt.show()
plt.savefig("City Longitude vs. Windspeed(mph).jpeg")
